# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from scipy.special import comb

# %% [markdown]
# ## Initialize Dataset \& Weights

# %%
def init_(p, n):
    
    """ Initializes system parameters.
    
    :param p: The number of training sample
    :param n: The number features (dimensions)
    :returns:
        x: The training sample
        s: The true labels of training sample
        w: The weight vector      
    """

    # Generate dataset with samples that follow Gaussian distribution
    mu = np.zeros(p) 
    sigma = np.ones(p)
    # No correlation between features
    cov = np.eye(p)
    x = np.random.multivariate_normal(mu, cov, n).T

    # For the P points, randomly assign a label (either +1 or -1) with equal probability
    s = random.choices( [1, -1], weights=[1/2, 1/2], k=p )
    s = np.array(s)

    # Initialize weights for a single neuron and each feature
    w = np.zeros(n)

    return x, s, w

# %% [markdown]
# ## Plot the Probability of being Linearly Separable

# %%
def successfulPlot(A, prob, label):
    
    """ Plots the fraction Pls = C(P, N)/2^P of linearly separable functions versus a = P/N
    
    :param A: The ratio of P to N
    :param prob: The probability of being linearly separable 

    """
    
    plt.suptitle("The fraction Pls = C(P, N)/2^P of linearly separable functions versus α = P/N", fontsize=14,\
                 fontweight="bold")
    plt.xlabel("a = P/N")
    plt.ylabel("C(P,N) / 2^P")
    plt.plot(A, prob, label=label)

# %% [markdown]
# ## Rosenblatt Perceptron Algorithm Implementation

# %%
def rosenblattPerceptron(x, s, w, P, c): 
    
    """ Implements Rosenblatt-Perceptron algorithm
    
    :param x: The training sample
    :param s: The true labels of training sample
    :param w: The weight vector
    :param P: The number of training samples
    :param c: The margin of whether weights change

    """
    
    for i in range(epochs):

        E = np.array([])
        
        for j in range(P):
            # Predict the labels
            E = np.append(E, x[j].dot(w.T)*s[j])

            # Update weights in case predicted value != true value
            if (E[j] <= c):
                w = w + (x[j] * s[j])/N

        # Stop iterating when all predicted values equal true values
        if (np.all(E > c)):
            print("All instances are predicted correctly")
            break
            
    print("The accuracy of the model for N =", +N, "and P =", +P, "equals:", +np.mean(E > c), "\n")
    
    return np.mean(E > c)

# %% [markdown]
# ## The Capacity of a Hyperplane

# %%
# Number of features (columns)
N = 40
# The different ratios of P to N
A = np.arange(0.75, 3.25, 0.25)
# The margin of whether weights change
c = 0
# Initialize number of epochs
epochs = 50
# Number of repeated datasets
n = 50
prob = np.array([])

for a in A:
    accuracy = np.array([])
    # Number of training samples (rows)
    P = int(a*N) 
    
    # Generate n independent datasets
    for j in range(n):
        # Initialize training samples given certain N and P 
        x, s, w = init_(P, N)
        # Run Rosenblatt-Perceptron algorithm
        accuracy = np.append(accuracy, rosenblattPerceptron(x, s, w, P, c) )
        
    prob = np.append(prob, np.sum(accuracy[accuracy==1])/n)

plt.figure(figsize=(8, 5), dpi=80)
successfulPlot(A, prob, 'Probability of successful runs')
plt.legend(loc='best')
plt.show()
# Out:
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.6833333333333333
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.8
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7833333333333333
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7833333333333333
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.9166666666666666
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.85
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.9333333333333333
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.85
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7666666666666667
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7666666666666667
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.8666666666666667
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.9833333333333333
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8285714285714286
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.9571428571428572
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7571428571428571
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7714285714285715
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8142857142857143
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7428571428571429
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7714285714285715
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7142857142857143
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8571428571428571
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8714285714285714
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.9
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8571428571428571
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8428571428571429
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8285714285714286
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7142857142857143
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7714285714285715
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6142857142857143
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7714285714285715
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.9571428571428572
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8428571428571429
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7857142857142857
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.9142857142857143
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7714285714285715
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8857142857142857
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7428571428571429
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7428571428571429
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6714285714285714
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8142857142857143
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7714285714285715
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8285714285714286
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7857142857142857
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7714285714285715
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.9
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6428571428571429
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6875
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.8625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.8125
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.8125
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6875
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.725
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.8
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.65
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.775
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6875
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.775
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.775
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.825
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.4375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.8625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.675
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.8375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.75
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.8625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.65
# The accuracy of the model for N = 40 and P = 80 equals: 0.5375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6875
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6125
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.65
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.65
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.725
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7875
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.775
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.8625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.75
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.8125
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.8
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.9
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.825
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6875
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6111111111111112
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7666666666666667
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5888888888888889
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7444444444444445
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.8555555555555555
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6555555555555556
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7555555555555555
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6222222222222222
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7777777777777778
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5444444444444444
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5111111111111111
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7444444444444445
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6111111111111112
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6888888888888889
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.8666666666666667
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5666666666666667
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6333333333333333
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.8
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6555555555555556
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6444444444444445
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7333333333333333
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6333333333333333
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7888888888888889
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5666666666666667
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7111111111111111
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.8222222222222222
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5888888888888889
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7333333333333333
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.8333333333333334
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7555555555555555
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7111111111111111
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6777777777777778
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6555555555555556
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5111111111111111
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6333333333333333
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6666666666666666
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6555555555555556
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7222222222222222
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6666666666666666
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5111111111111111
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7777777777777778
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6222222222222222
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.8
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.58
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.72
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.55
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.69
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.57
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.67
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.7
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.73
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.59
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.59
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.54
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.66
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.69
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.71
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.59
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.77
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.52
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.81
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.64
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.74
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.74
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.61
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.66
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.57
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.64
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.73
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.64
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.62
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.69
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.63
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.59
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.58
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.54
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.7
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.68
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.62
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.55
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.69
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.69
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.65
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.66
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.59
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.61
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.62
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.53
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.66
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.64
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6454545454545455
# The accuracy of the model for N = 40 and P = 110 equals: 0.5272727272727272
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6909090909090909
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5636363636363636
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5636363636363636
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5818181818181818
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6181818181818182
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.4818181818181818
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5818181818181818
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5727272727272728
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.7272727272727273
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6272727272727273
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.7272727272727273
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6090909090909091
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6090909090909091
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5545454545454546
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5454545454545454
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6181818181818182
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5818181818181818
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.7272727272727273
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5727272727272728
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5363636363636364
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6727272727272727
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5727272727272728
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5181818181818182
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5181818181818182
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6272727272727273
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5545454545454546
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5909090909090909
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6181818181818182
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6727272727272727
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.7090909090909091
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6636363636363637
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6727272727272727
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6090909090909091
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6454545454545455
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.4818181818181818
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6909090909090909
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5363636363636364
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6181818181818182
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5454545454545454
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6727272727272727
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6181818181818182
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5909090909090909
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6181818181818182
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5833333333333334
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.49166666666666664
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5666666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.625
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5666666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5583333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6083333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5083333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.55
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6083333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6916666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6083333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6666666666666666
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5166666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5833333333333334
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.55
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6166666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6583333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5583333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6083333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.44166666666666665
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.7166666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5916666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5333333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5083333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.675
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6666666666666666
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.48333333333333334
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6166666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.55
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5333333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6333333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5916666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5916666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.525
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6166666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.49166666666666664
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.575
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.425
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.45
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5083333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.55
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6583333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5333333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6333333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.45
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.65

# %% [markdown]
# ### Extension-1
#
# Observe the behavior of $Q_{l.s.}(α)$ for different system sizes $N$. Does it approach a step function with increasing $N$, as predicted by the theory? To this end, repeat the above experiments
# for several larger values of $N$. For this study, you might want to consider a limited range of
# $α-$values, e.g., $1.5 \leq α\leq 2.5$. and perhaps consider a smaller increment of $α$ in this interval.

# %%
# Number of features (columns)
N = [5, 20, 40, 100]
# The different ratios of P to N
A = np.arange(0.75, 3.25, 0.25)
# The margin of whether weights change
c = 0
# Initialize number of epochs
epochs = 50
# Number of repeated datasets
n = 10

for N in N:
    prob = np.array([])
    for a in A:
        accuracy = np.array([])
        # Number of training samples (rows)
        P = int(a*N) 

        # Generate n independent datasets given certain P and N
        for j in range(n):
            # Initialize training samples
            x, s, w = init_(P, N)
            # Run Rosenblatt-Perceptron algorithm
            accuracy = np.append(accuracy, rosenblattPerceptron(x, s, w, P, c) )

        prob = np.append(prob, np.sum(accuracy[accuracy==1])/n)

    successfulPlot(A, prob, 'Probability of successful runs')
    
plt.show()
# Out:
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 3 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 3 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 3 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 3 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 3 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 3 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 3 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 3 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 3 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 3 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 5 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 5 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 5 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 5 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 5 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 5 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 5 equals: 1.0
#
# The accuracy of the model for N = 5 and P = 5 equals: 0.6
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 5 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 5 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 6 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 6 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 6 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 6 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 6 equals: 1.0
#
# The accuracy of the model for N = 5 and P = 6 equals: 0.16666666666666666
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 6 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 6 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 6 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 6 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 7 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 7 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 7 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 7 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 7 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 7 equals: 1.0
#
# The accuracy of the model for N = 5 and P = 7 equals: 0.7142857142857143
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 7 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 7 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 7 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 8 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 8 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 8 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 8 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 8 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 8 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 8 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 8 equals: 1.0
#
# The accuracy of the model for N = 5 and P = 8 equals: 0.625
#
# The accuracy of the model for N = 5 and P = 8 equals: 0.75
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 10 equals: 1.0
#
# The accuracy of the model for N = 5 and P = 10 equals: 0.5
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 10 equals: 1.0
#
# The accuracy of the model for N = 5 and P = 10 equals: 0.5
#
# The accuracy of the model for N = 5 and P = 10 equals: 0.1
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 10 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 10 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 10 equals: 1.0
#
# The accuracy of the model for N = 5 and P = 10 equals: 0.4
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 10 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 11 equals: 1.0
#
# The accuracy of the model for N = 5 and P = 11 equals: 0.5454545454545454
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 11 equals: 1.0
#
# The accuracy of the model for N = 5 and P = 11 equals: 0.2727272727272727
#
# The accuracy of the model for N = 5 and P = 11 equals: 0.6363636363636364
#
# The accuracy of the model for N = 5 and P = 11 equals: 0.9090909090909091
#
# The accuracy of the model for N = 5 and P = 11 equals: 0.36363636363636365
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 11 equals: 1.0
#
# The accuracy of the model for N = 5 and P = 11 equals: 0.7272727272727273
#
# The accuracy of the model for N = 5 and P = 11 equals: 0.8181818181818182
#
# The accuracy of the model for N = 5 and P = 12 equals: 0.5833333333333334
#
# The accuracy of the model for N = 5 and P = 12 equals: 0.4166666666666667
#
# The accuracy of the model for N = 5 and P = 12 equals: 0.5833333333333334
#
# The accuracy of the model for N = 5 and P = 12 equals: 0.9166666666666666
#
# The accuracy of the model for N = 5 and P = 12 equals: 0.6666666666666666
#
# The accuracy of the model for N = 5 and P = 12 equals: 0.5
#
# The accuracy of the model for N = 5 and P = 12 equals: 0.5
#
# The accuracy of the model for N = 5 and P = 12 equals: 0.5
#
# The accuracy of the model for N = 5 and P = 12 equals: 0.6666666666666666
#
# The accuracy of the model for N = 5 and P = 12 equals: 0.6666666666666666
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 13 equals: 1.0
#
# The accuracy of the model for N = 5 and P = 13 equals: 0.6923076923076923
#
# The accuracy of the model for N = 5 and P = 13 equals: 0.8461538461538461
#
# The accuracy of the model for N = 5 and P = 13 equals: 0.6153846153846154
#
# The accuracy of the model for N = 5 and P = 13 equals: 0.38461538461538464
#
# The accuracy of the model for N = 5 and P = 13 equals: 0.5384615384615384
#
# The accuracy of the model for N = 5 and P = 13 equals: 0.6153846153846154
#
# The accuracy of the model for N = 5 and P = 13 equals: 0.8461538461538461
#
# The accuracy of the model for N = 5 and P = 13 equals: 0.3076923076923077
#
# The accuracy of the model for N = 5 and P = 13 equals: 0.3076923076923077
#
# The accuracy of the model for N = 5 and P = 15 equals: 0.6
#
# The accuracy of the model for N = 5 and P = 15 equals: 0.4
#
# The accuracy of the model for N = 5 and P = 15 equals: 0.5333333333333333
#
# The accuracy of the model for N = 5 and P = 15 equals: 0.26666666666666666
#
# The accuracy of the model for N = 5 and P = 15 equals: 0.6666666666666666
#
# The accuracy of the model for N = 5 and P = 15 equals: 0.26666666666666666
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 15 equals: 1.0
#
# The accuracy of the model for N = 5 and P = 15 equals: 0.4666666666666667
#
# The accuracy of the model for N = 5 and P = 15 equals: 0.6666666666666666
#
# All instances are predicted correctly
# The accuracy of the model for N = 5 and P = 15 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 15 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 15 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 15 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 15 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 15 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 15 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 15 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 15 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 15 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 15 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 20 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 20 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 20 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 20 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 20 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 20 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 20 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 20 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 20 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 20 equals: 1.0
#
# The accuracy of the model for N = 20 and P = 25 equals: 0.76
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 25 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 25 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 25 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 25 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 25 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 25 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 25 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 25 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 25 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 30 equals: 1.0
#
# The accuracy of the model for N = 20 and P = 30 equals: 0.8666666666666667
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 30 equals: 1.0
#
# The accuracy of the model for N = 20 and P = 30 equals: 0.8333333333333334
#
# The accuracy of the model for N = 20 and P = 35 equals: 0.8571428571428571
#
# The accuracy of the model for N = 20 and P = 35 equals: 0.8571428571428571
#
# The accuracy of the model for N = 20 and P = 35 equals: 0.7428571428571429
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 35 equals: 1.0
#
# The accuracy of the model for N = 20 and P = 35 equals: 0.8285714285714286
#
# The accuracy of the model for N = 20 and P = 35 equals: 0.7714285714285715
#
# The accuracy of the model for N = 20 and P = 35 equals: 0.6571428571428571
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 35 equals: 1.0
#
# The accuracy of the model for N = 20 and P = 35 equals: 0.6857142857142857
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 35 equals: 1.0
#
# The accuracy of the model for N = 20 and P = 40 equals: 0.75
#
# The accuracy of the model for N = 20 and P = 40 equals: 0.675
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 40 equals: 1.0
#
# The accuracy of the model for N = 20 and P = 40 equals: 0.85
#
# The accuracy of the model for N = 20 and P = 40 equals: 0.825
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 40 equals: 1.0
#
# The accuracy of the model for N = 20 and P = 40 equals: 0.675
#
# The accuracy of the model for N = 20 and P = 40 equals: 0.625
#
# The accuracy of the model for N = 20 and P = 40 equals: 0.8
#
# The accuracy of the model for N = 20 and P = 40 equals: 0.75
#
# The accuracy of the model for N = 20 and P = 45 equals: 0.5555555555555556
#
# The accuracy of the model for N = 20 and P = 45 equals: 0.7111111111111111
#
# The accuracy of the model for N = 20 and P = 45 equals: 0.4666666666666667
#
# The accuracy of the model for N = 20 and P = 45 equals: 0.6666666666666666
#
# The accuracy of the model for N = 20 and P = 45 equals: 0.5777777777777777
#
# The accuracy of the model for N = 20 and P = 45 equals: 0.6
#
# The accuracy of the model for N = 20 and P = 45 equals: 0.5777777777777777
#
# The accuracy of the model for N = 20 and P = 45 equals: 0.6444444444444445
#
# The accuracy of the model for N = 20 and P = 45 equals: 0.8444444444444444
#
# The accuracy of the model for N = 20 and P = 45 equals: 0.7111111111111111
#
# The accuracy of the model for N = 20 and P = 50 equals: 0.66
#
# The accuracy of the model for N = 20 and P = 50 equals: 0.6
#
# The accuracy of the model for N = 20 and P = 50 equals: 0.64
#
# The accuracy of the model for N = 20 and P = 50 equals: 0.64
#
# The accuracy of the model for N = 20 and P = 50 equals: 0.62
#
# The accuracy of the model for N = 20 and P = 50 equals: 0.6
#
# The accuracy of the model for N = 20 and P = 50 equals: 0.64
#
# The accuracy of the model for N = 20 and P = 50 equals: 0.56
#
# The accuracy of the model for N = 20 and P = 50 equals: 0.82
#
# The accuracy of the model for N = 20 and P = 50 equals: 0.52
#
# The accuracy of the model for N = 20 and P = 55 equals: 0.6181818181818182
#
# The accuracy of the model for N = 20 and P = 55 equals: 0.5818181818181818
#
# The accuracy of the model for N = 20 and P = 55 equals: 0.5818181818181818
#
# The accuracy of the model for N = 20 and P = 55 equals: 0.5272727272727272
#
# The accuracy of the model for N = 20 and P = 55 equals: 0.5454545454545454
#
# The accuracy of the model for N = 20 and P = 55 equals: 0.6545454545454545
#
# The accuracy of the model for N = 20 and P = 55 equals: 0.509090909090909
#
# The accuracy of the model for N = 20 and P = 55 equals: 0.7272727272727273
#
# The accuracy of the model for N = 20 and P = 55 equals: 0.4909090909090909
#
# The accuracy of the model for N = 20 and P = 55 equals: 0.5454545454545454
#
# The accuracy of the model for N = 20 and P = 60 equals: 0.6166666666666667
#
# The accuracy of the model for N = 20 and P = 60 equals: 0.55
#
# The accuracy of the model for N = 20 and P = 60 equals: 0.5833333333333334
#
# The accuracy of the model for N = 20 and P = 60 equals: 0.5833333333333334
#
# The accuracy of the model for N = 20 and P = 60 equals: 0.6833333333333333
#
# The accuracy of the model for N = 20 and P = 60 equals: 0.6666666666666666
#
# The accuracy of the model for N = 20 and P = 60 equals: 0.5666666666666667
#
# The accuracy of the model for N = 20 and P = 60 equals: 0.48333333333333334
#
# The accuracy of the model for N = 20 and P = 60 equals: 0.6666666666666666
#
# The accuracy of the model for N = 20 and P = 60 equals: 0.55
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.64
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.9
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7333333333333333
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.95
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.8666666666666667
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8714285714285714
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6714285714285714
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6714285714285714
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8714285714285714
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.5571428571428572
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8428571428571429
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8571428571428571
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7125
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.575
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.8
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7125
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6875
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.65
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.9
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6444444444444445
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7666666666666667
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7333333333333333
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6333333333333333
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7666666666666667
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.8444444444444444
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6333333333333333
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7333333333333333
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.68
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.61
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.66
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.59
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.79
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.62
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.72
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.72
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.44
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.5
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5909090909090909
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5545454545454546
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5181818181818182
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6727272727272727
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6727272727272727
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6545454545454545
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5727272727272728
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6454545454545455
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6545454545454545
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5545454545454546
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.675
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.7
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.55
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.575
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.675
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.65
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6083333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.65
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.65
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5916666666666667
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 75 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 75 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 75 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 75 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 75 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 75 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 75 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 75 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 75 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 75 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 100 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 100 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 100 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 100 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 100 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 100 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 100 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 100 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 100 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 100 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 125 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 125 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 125 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 125 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 125 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 125 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 125 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 125 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 125 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 125 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 150 equals: 1.0
#
# The accuracy of the model for N = 100 and P = 150 equals: 0.8733333333333333
#
# The accuracy of the model for N = 100 and P = 150 equals: 0.9466666666666667
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 150 equals: 1.0
#
# The accuracy of the model for N = 100 and P = 150 equals: 0.9666666666666667
#
# The accuracy of the model for N = 100 and P = 150 equals: 0.86
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 150 equals: 1.0
#
# The accuracy of the model for N = 100 and P = 150 equals: 0.9533333333333334
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 150 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 100 and P = 150 equals: 1.0
#
# The accuracy of the model for N = 100 and P = 175 equals: 0.7828571428571428
#
# The accuracy of the model for N = 100 and P = 175 equals: 0.8285714285714286
#
# The accuracy of the model for N = 100 and P = 175 equals: 0.84
#
# The accuracy of the model for N = 100 and P = 175 equals: 0.8457142857142858
#
# The accuracy of the model for N = 100 and P = 175 equals: 0.7542857142857143
#
# The accuracy of the model for N = 100 and P = 175 equals: 0.7314285714285714
#
# The accuracy of the model for N = 100 and P = 175 equals: 0.9542857142857143
#
# The accuracy of the model for N = 100 and P = 175 equals: 0.8
#
# The accuracy of the model for N = 100 and P = 175 equals: 0.8285714285714286
#
# The accuracy of the model for N = 100 and P = 175 equals: 0.8
#
# The accuracy of the model for N = 100 and P = 200 equals: 0.68
#
# The accuracy of the model for N = 100 and P = 200 equals: 0.61
#
# The accuracy of the model for N = 100 and P = 200 equals: 0.78
#
# The accuracy of the model for N = 100 and P = 200 equals: 0.825
#
# The accuracy of the model for N = 100 and P = 200 equals: 0.7
#
# The accuracy of the model for N = 100 and P = 200 equals: 0.725
#
# The accuracy of the model for N = 100 and P = 200 equals: 0.72
#
# The accuracy of the model for N = 100 and P = 200 equals: 0.755
#
# The accuracy of the model for N = 100 and P = 200 equals: 0.715
#
# The accuracy of the model for N = 100 and P = 200 equals: 0.67
#
# The accuracy of the model for N = 100 and P = 225 equals: 0.6266666666666667
#
# The accuracy of the model for N = 100 and P = 225 equals: 0.6977777777777778
#
# The accuracy of the model for N = 100 and P = 225 equals: 0.7155555555555555
#
# The accuracy of the model for N = 100 and P = 225 equals: 0.7022222222222222
#
# The accuracy of the model for N = 100 and P = 225 equals: 0.7377777777777778
#
# The accuracy of the model for N = 100 and P = 225 equals: 0.6844444444444444
#
# The accuracy of the model for N = 100 and P = 225 equals: 0.7422222222222222
#
# The accuracy of the model for N = 100 and P = 225 equals: 0.5688888888888889
#
# The accuracy of the model for N = 100 and P = 225 equals: 0.6444444444444445
#
# The accuracy of the model for N = 100 and P = 225 equals: 0.7155555555555555
#
# The accuracy of the model for N = 100 and P = 250 equals: 0.728
#
# The accuracy of the model for N = 100 and P = 250 equals: 0.516
#
# The accuracy of the model for N = 100 and P = 250 equals: 0.692
#
# The accuracy of the model for N = 100 and P = 250 equals: 0.676
#
# The accuracy of the model for N = 100 and P = 250 equals: 0.576
#
# The accuracy of the model for N = 100 and P = 250 equals: 0.648
#
# The accuracy of the model for N = 100 and P = 250 equals: 0.596
#
# The accuracy of the model for N = 100 and P = 250 equals: 0.612
#
# The accuracy of the model for N = 100 and P = 250 equals: 0.548
#
# The accuracy of the model for N = 100 and P = 250 equals: 0.724
#
# The accuracy of the model for N = 100 and P = 275 equals: 0.6145454545454545
#
# The accuracy of the model for N = 100 and P = 275 equals: 0.6436363636363637
#
# The accuracy of the model for N = 100 and P = 275 equals: 0.6581818181818182
#
# The accuracy of the model for N = 100 and P = 275 equals: 0.6290909090909091
#
# The accuracy of the model for N = 100 and P = 275 equals: 0.5890909090909091
#
# The accuracy of the model for N = 100 and P = 275 equals: 0.6145454545454545
#
# The accuracy of the model for N = 100 and P = 275 equals: 0.5854545454545454
#
# The accuracy of the model for N = 100 and P = 275 equals: 0.7018181818181818
#
# The accuracy of the model for N = 100 and P = 275 equals: 0.5854545454545454
#
# The accuracy of the model for N = 100 and P = 275 equals: 0.5963636363636363
#
# The accuracy of the model for N = 100 and P = 300 equals: 0.5933333333333334
#
# The accuracy of the model for N = 100 and P = 300 equals: 0.6166666666666667
#
# The accuracy of the model for N = 100 and P = 300 equals: 0.6033333333333334
#
# The accuracy of the model for N = 100 and P = 300 equals: 0.58
#
# The accuracy of the model for N = 100 and P = 300 equals: 0.5766666666666667
#
# The accuracy of the model for N = 100 and P = 300 equals: 0.65
#
# The accuracy of the model for N = 100 and P = 300 equals: 0.5833333333333334
#
# The accuracy of the model for N = 100 and P = 300 equals: 0.62
#
# The accuracy of the model for N = 100 and P = 300 equals: 0.6166666666666667
#
# The accuracy of the model for N = 100 and P = 300 equals: 0.57

# %% [markdown]
# ### Extension-2
#
# Determine the embedding strenghts $\chi^\mu$ (or formulate the algorithm in terms of the $\chi^\mu$) to
# obtain a histogram which reflects their frequency in the successful cases upon convergence
# of the training.

# %%
def rosenblattPerceptronEmb(x, s, w, P, c): 
    
    """ Implements Rosenblatt-Perceptron algorithm with updates of the embedding strengths
    
    :param x: The training sample
    :param s: The true labels of training sample
    :param w: The weight vector
    :param P: The number of training samples
    :param c: The margin of whether weights change

    """
    
    # Array of the embedding strengths (initialization outside of the epochs loop, right?)
    es = [0]*P

        
    for i in range(epochs):

        E = np.array([])
        
        for j in range(P):
            # Predict the labels
            E = np.append(E, x[j].dot(w.T)*s[j])

            # Update weights and increase corresponding embedding strength in case predicted value != true value
            if (E[j] <= c):
                w = w + (x[j] * s[j])/N
                es[j] = es[j] + 1

        # Stop iterating when all predicted values equal true values
        if (np.all(E > c)):
            print("All instances are predicted correctly")
            break
            
    print("The accuracy of the model for N =", +N, "and P =", +P, "equals:", +np.mean(E > c))
    print("Embedding strengths:",es, "\n")
    return np.mean(E > c),es

# %%
# Number of features (columns)
N = 20
# The different ratios of P to N
A = np.arange(0.75, 3.25, 0.25)
# The margin of whether weights change
c = 0
# Initialize number of epochs
epochs = 50
# Number of repeated datasets
n = 1
prob = np.array([])
# Initialize array of embedding strengths
emb_strengths = []

for a in A:
    # Initialize array of accuracies
    accuracy = np.array([])
    # Number of training samples (rows)
    P = int(a*N) 
    
    # Generate n independent datasets
    for j in range(n):
        # Initialize training samples given certain N and P 
        x, s, w = init_(P, N)
        # Run Rosenblatt-Perceptron algorithm
        acc,es = rosenblattPerceptronEmb(x, s, w, P, c)
        accuracy = np.append(accuracy, acc)
        emb_strengths.append(es)
        
    prob = np.append(prob, np.sum(accuracy[accuracy==1])/n)

# Plot histogram of embedding strenths of successful runs
for i in range(len(prob)):
    if prob[i] == 1:
        plt.suptitle("Histogram of embedding strenths")
        plt.xlabel("Number of updates")
        plt.ylabel("Frequency")
        plt.hist(emb_strengths[i])
#         plt.savefig('emb_str'+ str(i))
#         plt.clf()
        plt.show()
# Out:
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 15 equals: 1.0
# Embedding strengths: [4, 1, 0, 3, 2, 1, 2, 2, 3, 4, 0, 1, 0, 2, 2]
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 20 equals: 1.0
# Embedding strengths: [1, 1, 0, 2, 3, 0, 1, 0, 1, 2, 1, 1, 0, 2, 1, 2, 0, 1, 0, 0]
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 25 equals: 1.0
# Embedding strengths: [1, 4, 3, 2, 3, 3, 2, 3, 1, 5, 3, 0, 1, 2, 2, 0, 2, 0, 1, 4, 1, 5, 5, 0, 0]
#
# The accuracy of the model for N = 20 and P = 30 equals: 0.8
# Embedding strengths: [10, 45, 0, 27, 18, 3, 3, 19, 0, 22, 1, 33, 1, 0, 49, 0, 22, 17, 6, 0, 0, 32, 24, 4, 0, 14, 37, 12, 24, 10]
#
# All instances are predicted correctly
# The accuracy of the model for N = 20 and P = 35 equals: 1.0
# Embedding strengths: [3, 5, 0, 2, 43, 27, 0, 5, 1, 36, 4, 21, 13, 11, 14, 2, 0, 6, 0, 0, 12, 23, 2, 0, 7, 35, 24, 14, 0, 0, 0, 2, 0, 31, 1]
#
# The accuracy of the model for N = 20 and P = 40 equals: 0.7
# Embedding strengths: [46, 12, 30, 1, 23, 5, 1, 38, 9, 35, 10, 6, 40, 19, 1, 50, 9, 24, 0, 9, 13, 1, 10, 32, 48, 50, 0, 2, 50, 37, 12, 0, 28, 2, 33, 45, 34, 10, 24, 3]
#
# The accuracy of the model for N = 20 and P = 45 equals: 0.6
# Embedding strengths: [12, 1, 50, 50, 1, 32, 25, 2, 30, 50, 0, 13, 44, 22, 1, 15, 27, 17, 1, 21, 46, 0, 23, 50, 1, 9, 1, 17, 0, 43, 9, 0, 50, 50, 2, 34, 0, 10, 0, 46, 8, 1, 0, 45, 0]
#
# The accuracy of the model for N = 20 and P = 50 equals: 0.74
# Embedding strengths: [49, 0, 20, 1, 0, 1, 37, 34, 21, 15, 2, 0, 0, 0, 21, 0, 0, 49, 40, 48, 2, 0, 0, 1, 2, 7, 1, 7, 47, 15, 0, 20, 47, 15, 0, 6, 35, 4, 46, 12, 25, 49, 10, 26, 48, 4, 10, 49, 0, 16]
#
# The accuracy of the model for N = 20 and P = 55 equals: 0.45454545454545453
# Embedding strengths: [50, 50, 24, 50, 49, 31, 48, 18, 43, 27, 25, 0, 45, 4, 2, 38, 13, 21, 33, 49, 9, 34, 14, 14, 47, 45, 50, 50, 50, 3, 16, 49, 0, 2, 29, 43, 1, 30, 2, 44, 50, 0, 24, 6, 0, 13, 50, 36, 7, 0, 42, 1, 33, 18, 35]
#
# The accuracy of the model for N = 20 and P = 60 equals: 0.65
# Embedding strengths: [1, 1, 39, 4, 0, 28, 1, 0, 0, 49, 49, 23, 1, 22, 48, 15, 0, 0, 48, 45, 0, 1, 47, 7, 0, 0, 0, 3, 0, 28, 22, 0, 50, 6, 42, 36, 0, 46, 0, 7, 0, 28, 0, 0, 33, 43, 27, 1, 1, 13, 15, 0, 19, 0, 16, 50, 33, 18, 0, 0]

# %% [markdown]
# ### Extension-3
#
# Consider a non-zero value of c as introduced in class for updates when $E_\mu\leq c$. Does the
# choice of $c$ influence the results in terms of $Q_{l.s.}$?

# %%
# Number of features (columns)
N = 40
# The different ratios of P to N
A = np.arange(0.75, 3.25, 0.25)
# The margin of whether weights change
c = 1
# Initialize number of epochs
epochs = 50
# Number of repeated datasets
n = 50
prob = np.array([])

for a in A:
    accuracy = np.array([])
    # Number of training samples (rows)
    P = int(a*N) 
    
    # Generate n independent datasets
    for j in range(n):
        # Initialize training samples given certain N and P 
        x, s, w = init_(P, N)
        # Run Rosenblatt-Perceptron algorithm
        accuracy = np.append(accuracy, rosenblattPerceptron(x, s, w, P, c) )
        
    prob = np.append(prob, np.sum(accuracy[accuracy==1])/n)

plt.figure(figsize=(8, 5), dpi=80)
successfulPlot(A, prob, 'Probability of successful runs')
plt.legend(loc='best')
plt.show()
# Out:
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 30 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 40 equals: 0.875
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 40 equals: 0.725
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 40 equals: 0.875
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 40 equals: 0.925
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 40 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.9
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.82
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.78
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.72
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.84
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.84
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.78
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.82
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.92
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.84
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.84
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.68
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.72
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.94
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.8
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.88
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.66
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.86
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.8
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 50 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.86
#
# The accuracy of the model for N = 40 and P = 50 equals: 0.74
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.6833333333333333
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.9166666666666666
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7666666666666667
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.6166666666666667
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7333333333333333
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.8833333333333333
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.6666666666666666
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.8
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.8
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.6333333333333333
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7833333333333333
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.8333333333333334
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.8166666666666667
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.8
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7833333333333333
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.9
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.9
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.75
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7666666666666667
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.9
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7333333333333333
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7666666666666667
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7666666666666667
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7833333333333333
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7833333333333333
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.6333333333333333
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.85
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.8
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.8333333333333334
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.6666666666666666
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.8833333333333333
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.8166666666666667
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.85
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.8333333333333334
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.75
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7333333333333333
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 60 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.7
#
# The accuracy of the model for N = 40 and P = 60 equals: 0.65
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7428571428571429
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6857142857142857
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8428571428571429
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6428571428571429
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6428571428571429
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7285714285714285
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6428571428571429
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8857142857142857
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7142857142857143
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.9571428571428572
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6714285714285714
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7142857142857143
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 70 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7142857142857143
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7142857142857143
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7571428571428571
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.5857142857142857
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7857142857142857
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6428571428571429
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6571428571428571
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6571428571428571
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.5428571428571428
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7714285714285715
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6857142857142857
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6714285714285714
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.9142857142857143
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6571428571428571
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.5857142857142857
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7714285714285715
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7571428571428571
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6857142857142857
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8428571428571429
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7714285714285715
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6285714285714286
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7428571428571429
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.6571428571428571
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8142857142857143
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7142857142857143
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7571428571428571
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.7571428571428571
#
# The accuracy of the model for N = 40 and P = 70 equals: 0.8142857142857143
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.725
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.5125
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.675
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.675
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.5875
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.5875
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.575
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.725
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.5125
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.725
#
# All instances are predicted correctly
# The accuracy of the model for N = 40 and P = 80 equals: 1.0
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.675
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6875
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.675
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.5375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6125
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.8375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7125
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.65
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.75
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7375
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.5875
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.8125
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6125
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6875
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7625
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.55
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.55
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7125
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.725
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.675
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6125
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.7125
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.6875
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.725
#
# The accuracy of the model for N = 40 and P = 80 equals: 0.5875
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6555555555555556
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6555555555555556
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5666666666666667
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5333333333333333
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6888888888888889
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6222222222222222
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7222222222222222
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5777777777777777
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.4111111111111111
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5555555555555556
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5444444444444444
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5444444444444444
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6444444444444445
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5111111111111111
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7222222222222222
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6111111111111112
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6666666666666666
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7555555555555555
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5777777777777777
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6111111111111112
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.8222222222222222
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6555555555555556
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7888888888888889
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6222222222222222
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5666666666666667
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5444444444444444
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6666666666666666
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5555555555555556
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7222222222222222
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5555555555555556
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6444444444444445
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6111111111111112
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7444444444444445
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6111111111111112
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6777777777777778
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5222222222222223
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6666666666666666
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6444444444444445
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5333333333333333
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7333333333333333
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.4777777777777778
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.6444444444444445
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5666666666666667
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.7555555555555555
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.43333333333333335
#
# The accuracy of the model for N = 40 and P = 90 equals: 0.5777777777777777
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.53
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.65
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.53
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.59
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.49
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.62
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.46
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.56
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.44
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.68
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.71
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.54
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.5
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.66
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.52
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.63
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.53
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.47
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.54
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.69
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.75
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.52
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.77
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.64
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.61
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.66
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.39
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.58
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.37
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.55
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.61
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.52
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.59
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.51
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.55
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.6
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.51
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.58
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.56
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.49
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.57
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.58
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.59
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.48
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.57
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.5
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.54
#
# The accuracy of the model for N = 40 and P = 100 equals: 0.56
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.4636363636363636
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.4818181818181818
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5363636363636364
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.7181818181818181
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.509090909090909
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.42727272727272725
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.37272727272727274
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5909090909090909
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.4909090909090909
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.37272727272727274
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5818181818181818
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.4090909090909091
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6181818181818182
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5181818181818182
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6272727272727273
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5818181818181818
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.7181818181818181
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.509090909090909
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.509090909090909
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.4636363636363636
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6363636363636364
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5636363636363636
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.43636363636363634
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5272727272727272
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.4818181818181818
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5454545454545454
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.4818181818181818
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.4727272727272727
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5363636363636364
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5454545454545454
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.4090909090909091
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.4818181818181818
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5363636363636364
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5272727272727272
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.4090909090909091
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5181818181818182
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.37272727272727274
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6272727272727273
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6454545454545455
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5545454545454546
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.4909090909090909
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.6181818181818182
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.509090909090909
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5909090909090909
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.5272727272727272
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.509090909090909
#
# The accuracy of the model for N = 40 and P = 110 equals: 0.4818181818181818
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.44166666666666665
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5666666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5333333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.425
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.48333333333333334
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.48333333333333334
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.49166666666666664
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.43333333333333335
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.49166666666666664
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6583333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.4583333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6583333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6333333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5166666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5916666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.4583333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.4583333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5333333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.525
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.475
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5333333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5666666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.45
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.4583333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.48333333333333334
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.4666666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.48333333333333334
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5333333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5333333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5416666666666666
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.525
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.475
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6333333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.4583333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.575
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5916666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5083333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.39166666666666666
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5583333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.48333333333333334
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.525
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.6916666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.475
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.525
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5333333333333333
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.5916666666666667
#
# The accuracy of the model for N = 40 and P = 120 equals: 0.4166666666666667

# %% [markdown]
# ### Extension-4
#
# Modify the algorithm by adding a clamped input to all feature vectors in order to find and
# count inhomogeneous perceptron solutions as well. Does the number of successful training
# processes change significantly?

# %%
# Number of features (columns)
N = 40
# The different ratios of P to N
A = np.arange(0.75, 3.25, 0.25)
# The margin of whether weights change
c = 0
# Initialize number of epochs
epochs = 50
# Number of repeated datasets
n = 50
prob = np.array([])
# Theta
theta = 1

for a in A:
    accuracy = np.array([])
    # Number of training samples (rows)
    P = int(a*N) 
    
    # Generate n independent datasets
    for j in range(n):
        # Initialize training samples given certain N and P 
        x, s, w = init_(P, N)
        # Add clamped input to input vector 
        x=np.c_[x, (-1)*np.ones(P)]
        # Add theta to weight vector
        w = np.append(w, theta)
        # Run Rosenblatt-Perceptron algorithm
        accuracy = np.append(accuracy, rosenblattPerceptron(x, s, w, P, c) )
        
    prob = np.append(prob, np.sum(accuracy[accuracy==1])/n)

plt.figure(figsize=(8, 5), dpi=80)
successfulPlot(A, prob, 'Probability of successful runs')
plt.legend(loc='best')
# plt.savefig("theta_08")
plt.show()
